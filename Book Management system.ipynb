# %%
import mysql.connector
from tkinter import*
from tkinter import messagebox

mydb = mysql.connector.connect(host='localhost',user='root',password='Pra2001!',database='BMS')
mycursor = mydb.cursor()


root = Tk()
root.title("Book Management System")
root.minsize(width=400,height=400)
root.geometry("600x500")

Canvas1 = Canvas(root) 
Canvas1.config(bg="#add8e6",width = 300, height = 340)
Canvas1.pack(expand=True,fill=BOTH)

headingFrame1 = Frame(root,bg="black",bd=5)
headingFrame1.place(relx=0.2,rely=0.1,relwidth=0.6,relheight=0.16)
headingLabel = Label(headingFrame1, text="Welcome to \n Book Management System", bg='#FFBB00', fg='black', font=('Courier',15))
headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

btn1 = Button(root,text="Login",bg='#FFBB00', fg='black',activebackground='orange',activeforeground='white', font=('Courier',15),command=login)
btn1.place(relx=0.28,rely=0.4, relwidth=0.45,relheight=0.1)
    
btn2 = Button(root,text="Register",bg='#FFBB00', fg='black',activebackground='orange',activeforeground='white', font=('Courier',15),command=Register)
btn2.place(relx=0.28,rely=0.5, relwidth=0.45,relheight=0.1)

btn3 = Button(root,text="Add book",bg='#FFBB00', fg='black',activebackground='orange',activeforeground='white', font=('Courier',15),command=addBook)
btn3.place(relx=0.28,rely=0.6, relwidth=0.45,relheight=0.1)

btn4 = Button(root,text="Available books",bg='#FFBB00', fg='black',activebackground='orange',activeforeground='white', font=('Courier',15),command=available)
btn4.place(relx=0.28,rely=0.7, relwidth=0.45,relheight=0.1)
    
btn5 = Button(root,text="Request book",bg='#FFBB00', fg='black',activebackground='orange',activeforeground='white', font=('Courier',15),command=requestbook)
btn5.place(relx=0.28,rely=0.8, relwidth=0.45,relheight=0.1)

root.mainloop()

# %%
from tkinter import*
from tkinter import messagebox
import mysql.connector
mydb = mysql.connector.connect(host='localhost',user='root',password='Pra2001!',database='BMS')
mycursor= mydb.cursor()

def Registerpage():
    
    name = userInfo1.get()
    address = userInfo2.get()
    gender = userInfo3.get()
    mobile_no = userInfo4.get()
    email = userInfo5.get()
    
    insertData = "insert into Register values ('"+name+"','"+address+"','"+gender+"','"+mobile_no+",'"+email+"'')"
    try:
        mycursor.execute(insertData)
        con.commit()
        messagebox.showinfo('Success',"You Have Registered successfully")
    except:
        messagebox.showinfo("Error","Information is insufficent")
    
    print(name)
    print(address)
    print(gender)
    print(mobile_no)
    print(email)
    root.destroy()
    
def Register(): 
    
    global userInfo1 ,userInfo2, userInfo3, userInfo4, userInfo5,Canvas1, con, mycursor, RegisterTable, root
    
    root = Tk()
    root.title("Register")
    root.minsize(width=400,height=400)
    root.geometry("600x500")
    
    mydb = mysql.connector.connect(host='localhost',user='root',password='Pra2001!',database='BMS')
    mycursor= mydb.cursor()
    
    # Enter Table Names here
    RegisterTable = "Register" # Book Table
    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#ff6e40")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#FFBB00",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
    headingLabel = Label(headingFrame1, text="Register", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
        
    
    lb1 = Label(labelFrame,text="Name : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.10, relheight=0.08)
        
    userInfo1 = Entry(labelFrame)
    userInfo1.place(relx=0.3,rely=0.10, relwidth=0.62, relheight=0.08)
        
    
    lb2 = Label(labelFrame,text="Address : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.25, relheight=0.08)
        
    userInfo2 = Entry(labelFrame)
    userInfo2.place(relx=0.3,rely=0.25, relwidth=0.62, relheight=0.08)
        
    
    lb3 = Label(labelFrame,text="Gender : ", bg='black', fg='white')
    lb3.place(relx=0.05,rely=0.45, relheight=0.08)
        
    sel=IntVar()
    rb1=Radiobutton(labelFrame,text='male',font=(14),bg='black',fg='white')
    rb1.config(variable=sel,value=1,command= processRadiobutton)
    rb1.place(relx=0.3,rely=0.45,relheight=0.08)
    rb2=Radiobutton(labelFrame,text='female',font=(14),bg='black',fg='white')
    rb2.config(variable=sel,value=2,command= processRadiobutton)
    rb2.place(relx=0.5,rely=0.45,relheight=0.08)
        
    
    lb4 = Label(labelFrame,text="Mobile No. : ", bg='black', fg='white')
    lb4.place(relx=0.05,rely=0.65, relheight=0.08)
        
    userInfo4 = Entry(labelFrame)
    userInfo4.place(relx=0.3,rely=0.65, relwidth=0.62, relheight=0.08)
    
    lb5 = Label(labelFrame,text="Email : ", bg='black', fg='white')
    lb5.place(relx=0.05,rely=0.80, relheight=0.08)
        
    userInfo5 = Entry(labelFrame)
    userInfo5.place(relx=0.3,rely=0.80, relwidth=0.62, relheight=0.08)
        
    #Submit Button
    SubmitBtn = Button(root,text="SUBMIT",bg='#d1ccc0', fg='black',command=Registerpage)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#f7f1e3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

def processRadiobutton():
    if sel.get()==1:
        userInfo3.get()==male
    elif sel.get()==2:
        userInfo.get()==female

# %%
import mysql.connector
from tkinter import*
from tkinter import messagebox
mydb = mysql.connector.connect(host='localhost',user='root',password='Pra2001!',database='BMS')
mycursor= mydb.cursor()

def loginpage():
    name = userInfo1.get()
    password = userInfo2.get()
    
    insertData = "INSERT INTO login values ('"+name+"','"+password+"')"
    try:
        mycursor.execute(insertData)
        mydb.commit()
        messagebox.showinfo("Login successful")
    except:
        messagebox.showinfo("Error","Information is insufficent")
    
    print(name)
    print(password)
    root.destroy()
    
def login(): 
    
    global userInfo1 ,userInfo2,Canvas1, mycursor, RegisterTable, root
    
    root = Tk()
    root.title("Login")
    root.minsize(width=400,height=400)
    root.geometry("600x500")
    
    # Enter Table Names here
    loginTable = "Login" # Book Table
    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#12a4d9")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#FFBB00",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
    headingLabel = Label(headingFrame1, text="Login", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
        
    
    lb1 = Label(labelFrame,text="Username : ", bg='black', fg='white',font=('calibri',15))
    lb1.place(relx=0.05,rely=0.2 ,relheight=0.08)
        
    userInfo1 = Entry(labelFrame)
    userInfo1.place(relx=0.3,rely=0.2 ,relwidth=0.62, relheight=0.08)
        
    
    lb2 = Label(labelFrame,text="Password : ", bg='black', fg='white',font=('calibri',15))
    lb2.place(relx=0.05,rely=0.28, relheight=0.8)
        
    userInfo2 = Entry(labelFrame)
    userInfo2.place(relx=0.3,rely=0.65, relwidth=0.62, relheight=0.08)
    
     #Submit Button
    SubmitBtn = Button(root,text="LOGIN",bg='#d1ccc0', fg='black',command=requestbook)
    SubmitBtn.place(relx=0.40,rely=0.9, relwidth=0.18,relheight=0.08)
    
    newbtn = Button(root,text='New user',bg='#d1ccc0',fg='black',command=Register)
    newbtn.place(relx=0.80,rely=0.9,relwidth=0.18,relheight=0.08)
    
    root.mainloop()

# %%
import mysql.connector
from tkinter import*
from tkinter import messagebox

def bookRegister():
    
    bid = bookInfo1.get()
    title = bookInfo2.get()
    author = bookInfo3.get()
    price = bookInfo4.get()
    
    insertBooks = "INSERT INTO books values ('"+bid+"','"+title+"','"+author+"','"+price+"')"
    try:
        mycursor.execute(insertBooks)
        mydb.commit()
        
        messagebox.showinfo('Success',"Book added successfully")
    except:
        messagebox.showinfo("Error","Can't add data into Database")
    
    print(bid)
    print(title)
    print(author)
    print(price)
    root.destroy()

def addBook(): 
    
    global bookInfo1 ,bookInfo2, bookInfo3, bookInfo4, Canvas1,bookTable, root
    
    root = Tk()
    root.title("Add book")
    root.minsize(width=400,height=400)
    root.geometry("600x500")
    
    mydb = mysql.connector.connect(host='localhost',user='root',password='Pra2001!',database='BMS')
    mycursor= mydb.cursor()
    
    # Enter Table Names here
    bookTable = "books" # Book Table
    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="grey")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#FFBB00",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
    headingLabel = Label(headingFrame1, text="Add Books", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
        
    # Book ID
    lb1 = Label(labelFrame,text="Book ID : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.2, relheight=0.08)
        
    bookInfo1 = Entry(labelFrame)
    bookInfo1.place(relx=0.3,rely=0.2, relwidth=0.62, relheight=0.08)
        
    # Title
    lb2 = Label(labelFrame,text="Title : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.35, relheight=0.08)
        
    bookInfo2 = Entry(labelFrame)
    bookInfo2.place(relx=0.3,rely=0.35, relwidth=0.62, relheight=0.08)
        
    # Book Author
    lb3 = Label(labelFrame,text="Author : ", bg='black', fg='white')
    lb3.place(relx=0.05,rely=0.50, relheight=0.08)
        
    bookInfo3 = Entry(labelFrame)
    bookInfo3.place(relx=0.3,rely=0.50, relwidth=0.62, relheight=0.08)
        
    # Book price
    lb4 = Label(labelFrame,text="Price(in RS) : ", bg='black', fg='white')
    lb4.place(relx=0.05,rely=0.65, relheight=0.08)
        
    bookInfo4 = Entry(labelFrame)
    bookInfo4.place(relx=0.3,rely=0.65, relwidth=0.62, relheight=0.08)
        
    #Submit Button
    SubmitBtn = Button(root,text="SUBMIT",bg='#d1ccc0', fg='black',command=bookRegister)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#f7f1e3', fg='black',command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

# %%
import mysql.connector
from tkinter import*
from tkinter import messagebox
mydb = mysql.connector.connect(host='localhost',user='root',password='Pra2001!',database='BMS')
mycursor= mydb.cursor()

bookTable = "books" 

def available(): 
    
    root = Tk()
    root.title("Available books")
    root.minsize(width=400,height=400)
    root.geometry("600x500")
    
    Canvas1 = Canvas(root) 
    Canvas1.config(bg="#12a4d9")
    Canvas1.pack(expand=True,fill=BOTH)
    headingFrame1 = Frame(root,bg="#FFBB00",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
    headingLabel = Label(headingFrame1, text="Available Books", bg='black', fg='white', font = ('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)
    y = 0.25
    Label(labelFrame, text="%-10s%-40s%-30s%-20s"%('BID','Title','Author','Price(in Rs)'),
    bg='black',fg='white').place(relx=0.07,rely=0.1)
    Label(labelFrame, text = "----------------------------------------------------------------------------",bg='black',fg='white').place (relx=0.05,rely=0.2)

    
    getBooks = "SELECT * FROM books"
    try:
        mycursor.execute(getBooks)
        mydb.commit()
        result=mycursor.fetchall()
        for i in result:
            Label(labelFrame,text="%-10s%-30s%-30s%-20s"%(i[0],i[1],i[2],i[3]) ,bg='black', fg='white').place(relx=0.07,rely=y)
            y += 0.1
            print(i)
    except:
        messagebox.showinfo("Failed to fetch files from database")
    
    quitBtn = Button(root,text="Quit",bg='#f7f1e3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.4,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

# %%
import mysql.connector
from tkinter import*
from tkinter import messagebox
mydb = mysql.connector.connect(host='localhost',user='root',password='Pra2001!',database='BMS')
mycursor= mydb.cursor()
def requestbook(): 
    
    root = Tk()
    root.title("Request book")
    root.minsize(width=400,height=400)
    root.geometry("600x500")
    
    mydb = mysql.connector.connect(host='localhost',user='root',password='Pra2001!',database='BMS')
    mycursor= mydb.cursor()
    
   
    
    # Enter Table Names here
    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="green")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#FFBB00",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
    headingLabel = Label(headingFrame1, text="Request Books", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
        
    
    lb1 = Label(labelFrame,text="Book ID : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.2, relheight=0.08)
        
    bookInfo1 = Entry(labelFrame)
    bookInfo1.place(relx=0.3,rely=0.2, relwidth=0.62, relheight=0.08)
        
    
    lb2 = Label(labelFrame,text="Book Name : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.35, relheight=0.08)
        
    bookInfo2 = Entry(labelFrame)
    bookInfo2.place(relx=0.3,rely=0.35, relwidth=0.62, relheight=0.08)
        
    
    lb3 = Label(labelFrame,text="Price(in RS) : ", bg='black', fg='white')
    lb3.place(relx=0.05,rely=0.50, relheight=0.08)
        
    bookInfo3 = Entry(labelFrame)
    bookInfo3.place(relx=0.3,rely=0.50, relwidth=0.62, relheight=0.08)
        
    orderbtn=Button(root,text='Order',bg='#d1ccc0', fg='black')
    orderbtn.place(relx=0.40,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()
